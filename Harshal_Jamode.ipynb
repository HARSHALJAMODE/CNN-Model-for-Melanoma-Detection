# %% [markdown]
# **Problem statement:** To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# **Importing Skin Cancer Data**

# %% [markdown]
# Importing all the important libraries

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
## If you are using the data by mounting the google drive, use the following :
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Defining the path for train and test images
## Todo: Update the paths of the train and test dataset
data_dir_train = pathlib.Path("/content/gdrive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train")
data_dir_test = pathlib.Path("/content/gdrive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Test")

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# **Create a dataset**
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# **Create Train and validation data set**
#
# Use 80% of the images for training, and 20% for validation.

# %%
## Write your train dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset

train_ds = tf.keras.utils.image_dataset_from_directory(
            data_dir_train,
            batch_size=batch_size,
            image_size=(img_height, img_width),
            seed=123,
            validation_split=0.2,
            subset='training',
            )
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
## Write your validation dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
val_ds = tf.keras.utils.image_dataset_from_directory(
            data_dir_train,
            batch_size=batch_size,
            image_size=(img_height, img_width),
            seed=123,
            validation_split=0.2,
            subset='validation',
            )
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
# List out all the classes of skin cancer and store them in a list. 
# You can find the class names in the class_names attribute on these datasets. 
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# **Visualize the data**

# %%
import matplotlib.pyplot as plt

### your code goes here, you can use training or validation data to visualize
for i in range(len(class_names)):
    filtered_ds = train_ds.filter(lambda x, l: tf.math.equal(l[0], i))
    for image, label in filtered_ds.take(1):
        ax = plt.subplot(3, 3, i+1)
        plt.imshow(image[0].numpy().astype('uint8'))
        plt.title(class_names[label.numpy()[0]])
        plt.axis('off')

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# **Create the model-1**
#
# This is a basic model without any data augmentationa and dropouts.

# %%
### Your code goes here

num_class = 9
model = tf.keras.Sequential([
    layers.Rescaling(scale = 1./255, input_shape = (180,180,3)),
    layers.Conv2D(32,3,padding='same',activation= 'relu'),
    layers.MaxPooling2D(pool_size = 2, strides = 2),    
    layers.Conv2D(64,3,padding='same',activation= 'relu'),
    layers.MaxPooling2D(pool_size = 2, strides = 2),
    layers.Conv2D(128,3,padding='same',activation= 'relu'),
    layers.MaxPooling2D(pool_size = 2, strides = 2),
    layers.Flatten(),
    layers.Dense(128,activation='relu'),
    layers.Dense(num_class, activation='softmax')
])

# %% [markdown]
# **Compile the model**

# %%
#Todo, choose an appropirate optimiser and loss function
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True),
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 90, 90, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 90, 90, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 45, 45, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 45, 45, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 22, 22, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 61952)             0
#
#  dense (Dense)               (None, 128)               7929984
#
#  dense_1 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 8,024,393
# Trainable params: 8,024,393
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 56/56 [==============================] - 236s 4s/step - loss: 2.0799 - accuracy: 0.2528 - val_loss: 1.7769 - val_accuracy: 0.3468
# Epoch 2/20
# 56/56 [==============================] - 117s 2s/step - loss: 1.6735 - accuracy: 0.4018 - val_loss: 1.6869 - val_accuracy: 0.4407
# Epoch 3/20
# 56/56 [==============================] - 117s 2s/step - loss: 1.4846 - accuracy: 0.4855 - val_loss: 1.4018 - val_accuracy: 0.5235
# Epoch 4/20
# 56/56 [==============================] - 119s 2s/step - loss: 1.4298 - accuracy: 0.5006 - val_loss: 1.4830 - val_accuracy: 0.4899
# Epoch 5/20
# 56/56 [==============================] - 119s 2s/step - loss: 1.3025 - accuracy: 0.5396 - val_loss: 1.3720 - val_accuracy: 0.5347
# Epoch 6/20
# 56/56 [==============================] - 119s 2s/step - loss: 1.2044 - accuracy: 0.5854 - val_loss: 1.4442 - val_accuracy: 0.5056
# Epoch 7/20
# 56/56 [==============================] - 119s 2s/step - loss: 1.1805 - accuracy: 0.5815 - val_loss: 1.3956 - val_accuracy: 0.5436
# Epoch 8/20
# 56/56 [==============================] - 117s 2s/step - loss: 1.1058 - accuracy: 0.6083 - val_loss: 1.4300 - val_accuracy: 0.5302
# Epoch 9/20
# 56/56 [==============================] - 119s 2s/step - loss: 0.9896 - accuracy: 0.6451 - val_loss: 1.4390 - val_accuracy: 0.5414
# Epoch 10/20
# 56/56 [==============================] - 119s 2s/step - loss: 0.9063 - accuracy: 0.6808 - val_loss: 1.5604 - val_accuracy: 0.5414
# Epoch 11/20
# 56/56 [==============================] - 119s 2s/step - loss: 0.8096 - accuracy: 0.7081 - val_loss: 1.5404 - val_accuracy: 0.5570
# Epoch 12/20
# 56/56 [==============================] - 119s 2s/step - loss: 0.7609 - accuracy: 0.7232 - val_loss: 1.6787 - val_accuracy: 0.5280
# Epoch 13/20
# 56/56 [==============================] - 119s 2s/step - loss: 0.6660 - accuracy: 0.7595 - val_loss: 1.7647 - val_accuracy: 0.5436
# Epoch 14/20
# 56/56 [==============================] - 117s 2s/step - loss: 0.6689 - accuracy: 0.7640 - val_loss: 1.8162 - val_accuracy: 0.5526
# Epoch 15/20
# 56/56 [==============================] - 119s 2s/step - loss: 0.5503 - accuracy: 0.8013 - val_loss: 1.8458 - val_accuracy: 0.5570
# Epoch 16/20
# 56/56 [==============================] - 119s 2s/step - loss: 0.4497 - accuracy: 0.8398 - val_loss: 2.0444 - val_accuracy: 0.5526
# Epoch 17/20
# 56/56 [==============================] - 119s 2s/step - loss: 0.4232 - accuracy: 0.8365 - val_loss: 2.1772 - val_accuracy: 0.5078
# Epoch 18/20
# 56/56 [==============================] - 119s 2s/step - loss: 0.3725 - accuracy: 0.8599 - val_loss: 2.2152 - val_accuracy: 0.5168
# Epoch 19/20
# 56/56 [==============================] - 117s 2s/step - loss: 0.3447 - accuracy: 0.8739 - val_loss: 1.9934 - val_accuracy: 0.5347
# Epoch 20/20
# 56/56 [==============================] - 117s 2s/step - loss: 0.3032 - accuracy: 0.8823 - val_loss: 2.2707 - val_accuracy: 0.5123

# %% [markdown]
# **Visualizing training results**

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# **Conclusion from Model-1**
#
# From the model 1 we can clearly see that the model is overfited.
#
# The difference between trian and validation Accuracy of the Mode is more than 20%.
#
# As we have less train data we can try models with Data augmentation

# %% [markdown]
# **Create the model-2: Manual augmentation**
#
# In this model lets try the manual data augmentation.

# %%
# Todo, after you have analysed the model fit history for presence of underfit or overfit, choose an appropriate data augumentation strategy. 
# Your code goes here

with tf.device('/gpu:0'):
    data_augmentation = tf.keras.Sequential([
        layers.RandomFlip("horizontal_and_vertical"),
        layers.RandomRotation(0.2),
    ])

# %%
# Todo, visualize how your augmentation strategy works for one instance of training image.
# Your code goes here

for image, label in train_ds.take(1):
        ax = plt.subplot(1, 2, 1)
        plt.imshow(image[0].numpy().astype('uint8'))
        plt.title(class_names[label.numpy()[0]])
        plt.axis('off')
        
        augmented = data_augmentation(image)
        ax = plt.subplot(1, 2, 2)
        plt.imshow(augmented[0].numpy().astype('uint8'))
        plt.title(class_names[label.numpy()[0]])
        plt.axis('off')

# %% [markdown]
# **compile and train the model**

# %%
## You can use Dropout layer if there is an evidence of overfitting in your findings


num_classes = 9
model = Sequential([
  data_augmentation,
  layers.Rescaling(1./255),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(128, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.30),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dropout(0.20),
  layers.Dense(num_classes,activation='softmax')
])

# %% [markdown]
# **Compiling the model**

# %%
## Your code goes here
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True),
              metrics=['accuracy'])

# %% [markdown]
# **Training the model**

# %%
## Your code goes here, note: train your model for 20 epochs
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 130s 2s/step - loss: 1.9364 - accuracy: 0.3119 - val_loss: 1.6595 - val_accuracy: 0.4049
# Epoch 2/20
# 56/56 [==============================] - 126s 2s/step - loss: 1.6962 - accuracy: 0.3772 - val_loss: 1.7483 - val_accuracy: 0.3557
# Epoch 3/20
# 56/56 [==============================] - 126s 2s/step - loss: 1.6529 - accuracy: 0.4269 - val_loss: 1.5995 - val_accuracy: 0.4452
# Epoch 4/20
# 56/56 [==============================] - 125s 2s/step - loss: 1.5098 - accuracy: 0.4715 - val_loss: 1.5304 - val_accuracy: 0.4787
# Epoch 5/20
# 56/56 [==============================] - 125s 2s/step - loss: 1.4741 - accuracy: 0.4916 - val_loss: 1.5028 - val_accuracy: 0.5056
# Epoch 6/20
# 56/56 [==============================] - 126s 2s/step - loss: 1.4543 - accuracy: 0.4821 - val_loss: 1.4700 - val_accuracy: 0.5168
# Epoch 7/20
# 56/56 [==============================] - 123s 2s/step - loss: 1.3752 - accuracy: 0.5179 - val_loss: 1.4443 - val_accuracy: 0.4922
# Epoch 8/20
# 56/56 [==============================] - 124s 2s/step - loss: 1.3807 - accuracy: 0.5039 - val_loss: 1.6928 - val_accuracy: 0.4720
# Epoch 9/20
# 56/56 [==============================] - 124s 2s/step - loss: 1.3732 - accuracy: 0.5195 - val_loss: 1.4566 - val_accuracy: 0.4832
# Epoch 10/20
# 56/56 [==============================] - 123s 2s/step - loss: 1.3161 - accuracy: 0.5279 - val_loss: 1.3348 - val_accuracy: 0.5324
# Epoch 11/20
# 56/56 [==============================] - 126s 2s/step - loss: 1.2896 - accuracy: 0.5474 - val_loss: 1.4013 - val_accuracy: 0.4989
# Epoch 12/20
# 56/56 [==============================] - 123s 2s/step - loss: 1.2618 - accuracy: 0.5441 - val_loss: 1.3812 - val_accuracy: 0.5280
# Epoch 13/20
# 56/56 [==============================] - 124s 2s/step - loss: 1.3227 - accuracy: 0.5290 - val_loss: 1.5899 - val_accuracy: 0.4810
# Epoch 14/20
# 56/56 [==============================] - 122s 2s/step - loss: 1.2679 - accuracy: 0.5497 - val_loss: 1.3075 - val_accuracy: 0.5526
# Epoch 15/20
# 56/56 [==============================] - 124s 2s/step - loss: 1.2401 - accuracy: 0.5592 - val_loss: 1.3900 - val_accuracy: 0.5190
# Epoch 16/20
# 56/56 [==============================] - 123s 2s/step - loss: 1.2323 - accuracy: 0.5513 - val_loss: 1.3579 - val_accuracy: 0.5347
# Epoch 17/20
# 56/56 [==============================] - 123s 2s/step - loss: 1.2385 - accuracy: 0.5580 - val_loss: 1.4523 - val_accuracy: 0.4787
# Epoch 18/20
# 56/56 [==============================] - 126s 2s/step - loss: 1.3084 - accuracy: 0.5312 - val_loss: 1.2859 - val_accuracy: 0.5615
# Epoch 19/20
# 56/56 [==============================] - 126s 2s/step - loss: 1.2395 - accuracy: 0.5485 - val_loss: 1.3428 - val_accuracy: 0.5302
# Epoch 20/20
# 56/56 [==============================] - 126s 2s/step - loss: 1.2078 - accuracy: 0.5647 - val_loss: 1.3564 - val_accuracy: 0.5749

# %% [markdown]
# **Visualizing the results**

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# **Conclusions from Model-2**
#
# The application of data augmentation and dropout layer clearly reduced the overfitting.
#
# As we can see difference between train and validation accuracy is reduced. and overall effeciency increased.

# %% [markdown]
# **Create the model-3: Automatic data augmentation**
#
# This model is based on Automatic data augmentation.

# %% [markdown]
# Checking data in each class

# %%
## Your code goes here.
class_count=[]
for i in class_names:
    class_count.append(len(list(data_dir_train.glob(i+'/*.jpg'))))
plt.figure(figsize=(20,10))
plt.bar(class_names,class_count)
# Out:
# <BarContainer object of 9 artists>

# %% [markdown]
# Using Automatic Augmentor.

# %%
# !pip install Augmentor
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Augmentor
#   Downloading Augmentor-0.2.10-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (4.64.1)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (7.1.2)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (1.21.6)
# Requirement already satisfied: future>=0.16.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (0.16.0)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.10

# %%
path_to_training_dataset='/content/gdrive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/'
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Initialised with 114 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F2E25ACAE90>: 100%|██████████| 500/500 [00:22<00:00, 21.87 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F2E25B72350>: 100%|██████████| 500/500 [00:22<00:00, 22.03 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F2E25B72AD0>: 100%|██████████| 500/500 [00:22<00:00, 21.96 Samples/s]

# %%
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)

# %% [markdown]
# **Lets see the distribution of augmented data after adding new images to the original training data.**

# %%
from glob import glob
path_list = [x for x in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]

# %%
dataframe_dict_new = dict(zip(path_list, lesion_list_new))

# %%
df2 = pd.DataFrame(list(dataframe_dict_new.items()),columns = ['Path','Label'])
#new_df = original_df.append(df2)

# %%
df2['Label'].value_counts()

# %% [markdown]
# **Train the model on the data created using Augmentor**

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# **Create a training dataset**

# %%
data_dir_train="/content/gdrive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train"
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'training',
  image_size=(img_height, img_width),
  batch_size=batch_size)

# %% [markdown]
# **Create a validation dataset**

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'validation',
  image_size=(img_height, img_width),
  batch_size=batch_size)

# %% [markdown]
# **Create the model**

# %%
## your code goes here
#CNN Model Architecture

#Sequential allows you to create models layer-by-layer  
model = Sequential()

model.add(layers.experimental.preprocessing.Rescaling(1./255,input_shape=(180,180,3)))   #Rescaling Layer

#First Convulation layer
model.add(layers.Conv2D(32,kernel_size=(3,3),activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))

#Second Convulation Layer
model.add(layers.Conv2D(64,kernel_size=(3,3),activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))

#Third Convulation Layer
model.add(layers.Conv2D(128,kernel_size=(3,3),activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))

#Dropout layer with 50% Fraction of the input units to drop.
model.add(layers.Dropout(0.5))

#Flatten Layer
##Keras.layers.flatten function flattens the multi-dimensional input tensors into a single dimension.
model.add(layers.Flatten())

#Dense Layer
model.add(layers.Dense(128,activation='relu'))

#Dropout layer with 25% Fraction of the input units to drop.
model.add(layers.Dropout(0.25))

#Dense Layer with softmax activation function.
#Softmax is an activation function that scales numbers/logits into probabilities.
model.add(layers.Dense(len(class_names),activation='softmax'))

model.summary()

# %% [markdown]
# **Compile your model**

# %%
## your code goes here
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# **Train your model**

# %%
epochs = 20
## Your code goes here, use 20 epochs.
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 169/169 [==============================] - 366s 2s/step - loss: 1.8661 - accuracy: 0.2895 - val_loss: 1.4754 - val_accuracy: 0.4276
# Epoch 2/20
# 169/169 [==============================] - 360s 2s/step - loss: 1.4789 - accuracy: 0.4330 - val_loss: 1.3098 - val_accuracy: 0.5234
# Epoch 3/20
# 169/169 [==============================] - 364s 2s/step - loss: 1.3361 - accuracy: 0.4931 - val_loss: 1.2599 - val_accuracy: 0.5278
# Epoch 4/20
# 169/169 [==============================] - 360s 2s/step - loss: 1.1986 - accuracy: 0.5428 - val_loss: 1.1021 - val_accuracy: 0.5895
# Epoch 5/20
# 169/169 [==============================] - 358s 2s/step - loss: 1.0779 - accuracy: 0.6014 - val_loss: 1.0295 - val_accuracy: 0.6206
# Epoch 6/20
# 169/169 [==============================] - 361s 2s/step - loss: 0.9779 - accuracy: 0.6419 - val_loss: 1.1568 - val_accuracy: 0.5976
# Epoch 7/20
# 169/169 [==============================] - 353s 2s/step - loss: 0.8491 - accuracy: 0.6825 - val_loss: 0.9341 - val_accuracy: 0.6904
# Epoch 8/20
# 169/169 [==============================] - 357s 2s/step - loss: 0.7390 - accuracy: 0.7337 - val_loss: 0.8651 - val_accuracy: 0.7127
# Epoch 9/20
# 169/169 [==============================] - 351s 2s/step - loss: 0.6549 - accuracy: 0.7589 - val_loss: 0.8098 - val_accuracy: 0.7327
# Epoch 10/20
# 169/169 [==============================] - 353s 2s/step - loss: 0.6237 - accuracy: 0.7672 - val_loss: 0.8405 - val_accuracy: 0.7409
# Epoch 11/20
# 169/169 [==============================] - 354s 2s/step - loss: 0.5575 - accuracy: 0.7917 - val_loss: 0.8241 - val_accuracy: 0.7506
# Epoch 12/20
# 169/169 [==============================] - 354s 2s/step - loss: 0.5041 - accuracy: 0.8151 - val_loss: 0.7876 - val_accuracy: 0.7661
# Epoch 13/20
# 169/169 [==============================] - 355s 2s/step - loss: 0.4880 - accuracy: 0.8214 - val_loss: 0.8273 - val_accuracy: 0.7416
# Epoch 14/20
# 169/169 [==============================] - 356s 2s/step - loss: 0.4396 - accuracy: 0.8368 - val_loss: 0.7834 - val_accuracy: 0.7817
# Epoch 15/20
# 169/169 [==============================] - 359s 2s/step - loss: 0.4313 - accuracy: 0.8388 - val_loss: 0.8082 - val_accuracy: 0.7899
# Epoch 16/20
# 169/169 [==============================] - 354s 2s/step - loss: 0.3824 - accuracy: 0.8579 - val_loss: 0.7868 - val_accuracy: 0.8025
# Epoch 17/20
# 169/169 [==============================] - 354s 2s/step - loss: 0.3929 - accuracy: 0.8531 - val_loss: 0.8087 - val_accuracy: 0.7854
# Epoch 18/20
# 169/169 [==============================] - 354s 2s/step - loss: 0.3730 - accuracy: 0.8615 - val_loss: 0.9877 - val_accuracy: 0.7736
# Epoch 19/20
# 169/169 [==============================] - 353s 2s/step - loss: 0.3231 - accuracy: 0.8765 - val_loss: 0.8216 - val_accuracy: 0.7988
# Epoch 20/20
# 169/169 [==============================] - 357s 2s/step - loss: 0.3342 - accuracy: 0.8730 - val_loss: 0.8566 - val_accuracy: 0.7832

# %% [markdown]
# **Visualize the model results**

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# **Conclusion from model-3**
#
# Class rebalance helped us to get rid of the overfitting and Hence data augmentation helps to reduce the overfitting.
#
# The performance of the model is similar on both training and validation data Both training and validatin accuracy have been increased.
#
# **The models giving Train accuracy of 0.8579 and Validation accuracy of 0.8025**
